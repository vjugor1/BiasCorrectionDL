# %% [markdown]
# # ClimateLearn Quickstart
#
# This notebook shows how to develop a weather forecasting model with deep learning in ClimateLearn from end-to-end. First, we install the library from the GitHub repository.

# %% [markdown]
# Mount the Google Drive file system, then import ClimateLearn and related libraries.

# %%
import sys
sys.path.append('/app')

from src.climate_learn import LitModule
from src.climate_learn import download_weatherbench
from src.climate_learn import convert_nc2npz
from src.climate_learn import IterDataModule
from src.climate_learn.utils import visualize_at_index, visualize_mean_bias
from src.climate_learn import load_downscaling_module
from src.climate_learn.data.processing.era5_constants import (
    DEFAULT_PRESSURE_LEVELS, PRESSURE_LEVEL_VARS)

import pytorch_lightning as pl
from pytorch_lightning.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    RichModelSummary,
    RichProgressBar,
)
from pytorch_lightning.loggers.tensorboard import TensorBoardLogger
import torch

# %%
from src.climate_learn.transforms import Mask, Denormalize

# %% [markdown]
# The downloaded and processed data is loaded into a PyTorch Lightning data module. In the following code cell, we use the following settings:
# - `subsample = 6`. The dataset is subsampled at 6 hour intervals; this is done so that training is faster, but one could also use no subsampling (_i.e._, `subsample = 1`, which is the default).
# - `pred_range = 24`. The model's objective is to predict `2m_temperature` 24 hours in the future.
# - `history = 3`. When making a prediction, the model is given data at time `t`, `t-subsample`, and `t-subsample*2`.
# - `task = "direct-forecasting"`. Given the inputs, the model directly predicts the outputs at `pred_range`. Other methods of forecasting are iterative forecasting and continuous forecasting. We refer to section 3 of [this paper by Rasp and Theurey](https://arxiv.org/pdf/2008.08626.pdf) for a description of these forecasting types.
#
# Note further that `in_vars` and `out_vars` are the same, meaning the model consumes historical temperature and geopotential as input and produces predicted temperature and geopotential as output.
#
# Before running this next code cell, we recommend switching to a GPU-accelerated runtime then re-running all code cells related to installation and library imports. You do _NOT_ need to re-download/process the data. Those should be saved to your Google Drive.

# %%
# CMIP
dm = IterDataModule(
    task="downscaling",
    inp_root_dir="/app/data/processed/cmip6-cmip6/LR",
    out_root_dir="/app/data/processed/cmip6-cmip6/HR",
    in_vars = ["air_temperature", "u_component_of_wind", "v_component_of_wind", "precipitation", "pressure_sea_level", "specific_humidity", "cloud_cover", "upward_heat_flux", "moisture_in_soil"],
    out_vars = ["air_temperature", "u_component_of_wind", "v_component_of_wind", "precipitation"],
    subsample=1,
    batch_size=512,
    num_workers=4,
)
dm.setup()

# %%
# Retrieve the shape of the 2m temperature data from the first item in the test dataset
temperature_shape = next(iter(dm.data_test.dataset.dataset))[0]["air_temperature"].shape
print(f"Shape of temperature data: {temperature_shape}")

# Get the shape of the first batch of data from the test dataloader
first_batch_shape = next(iter(dm.test_dataloader()))[0].shape
print(f"Shape of the first batch from test dataloader: {first_batch_shape}")

in_vars, out_vars = dm.get_data_variables()
in_shape, out_shape = dm.get_data_dims()
in_channels, in_height, in_width = in_shape[1:]
out_channels, out_height, out_width = out_shape[1:]

# Printing detailed information about input and output shapes for clarity
print(
    f"Input Channels = {in_channels}, Input Height = {in_height}, Input Width = {in_width}"
)
print(
    f"Output Channels = {out_channels}, Output Height = {out_height}, Output Width = {out_width}"
)
# Out:
# Shape of temperature data: (73, 96, 192)
# Shape of the first batch from test dataloader: torch.Size([146, 4, 96, 192])
# Input Channels = 4, Input Height = 96, Input Width = 192
# Output Channels = 4, Output Height = 192, Output Width = 384

# %% [markdown]
# Run baseline methods, climatology and persistence. Climatology uses the average value observed in the training data as its predictions. Persistence uses the last observed value as its predictio. For our setup, that would mean using the values of `2m_temperature` and `toa_incident_solar_radiation` at time `t` as the predictions for time `t+24`.

# %%
bicubic = load_downscaling_module(
                                data_module=dm,
                                architecture="bicubic-interpolation",
                                )

bilinear = load_downscaling_module(
                                data_module=dm,
                                architecture="bilinear-interpolation",
)

nearest = load_downscaling_module(
                                data_module=dm,
                                architecture="nearest-interpolation",
)

trainer = pl.Trainer(accelerator="cpu")

trainer.validate(bilinear, dm)
# trainer.validate(nearest, dm)
# trainer.validate(bicubic, dm)

trainer.test(bilinear, dm)
# trainer.test(nearest, dm)
# trainer.test(bicubic, dm)
# Out:
# GPU available: True (cuda), used: False
# Loading architecture: bicubic-interpolation
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading test loss: rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: bilinear-interpolation
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading test loss: rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: nearest-interpolation
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading test loss: rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/conda/envs/bias_correction/lib/python3.12/site-packages/pytorch_lightning/trainer/setup.py:187: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# Validation: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃          Validate metric          ┃           DataLoader 0            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      val/mean_bias:aggregate      │        0.07395106554031372        │
# │   val/mean_bias:air_temperature   │        0.18015289306640625        │
# │    val/mean_bias:precipitation    │       0.020407676696777344        │
# │ val/mean_bias:u_component_of_wind │        0.07797238230705261        │
# │ val/mean_bias:v_component_of_wind │       0.017271341755986214        │
# │         val/mse:aggregate         │        0.9971306920051575         │
# │      val/mse:air_temperature      │        0.04422309249639511        │
# │       val/mse:precipitation       │        1.4488933086395264         │
# │    val/mse:u_component_of_wind    │        1.0315771102905273         │
# │    val/mse:v_component_of_wind    │        1.4638293981552124         │
# │       val/pearson:aggregate       │        0.49231427907943726        │
# │    val/pearson:air_temperature    │        0.9785582423210144         │
# │     val/pearson:precipitation     │        0.2578556537628174         │
# │  val/pearson:u_component_of_wind  │        0.4858897030353546         │
# │  val/pearson:v_component_of_wind  │        0.24695348739624023        │
# │        val/rmse:aggregate         │         5.398252487182617         │
# │     val/rmse:air_temperature      │        4.4555206298828125         │
# │      val/rmse:precipitation       │         6.54288387298584          │
# │   val/rmse:u_component_of_wind    │         5.311598777770996         │
# │   val/rmse:v_component_of_wind    │         5.283006191253662         │
# └───────────────────────────────────┴───────────────────────────────────┘
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃            Test metric             ┃            DataLoader 0            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      test/mean_bias:aggregate      │        0.10918299108743668         │
# │   test/mean_bias:air_temperature   │         0.4095916748046875         │
# │    test/mean_bias:precipitation    │        0.005211532115936279        │
# │ test/mean_bias:u_component_of_wind │        0.02943168580532074         │
# │ test/mean_bias:v_component_of_wind │       -0.007502904627472162        │
# │       test/pearson:aggregate       │         0.471500962972641          │
# │    test/pearson:air_temperature    │         0.9770058393478394         │
# │     test/pearson:precipitation     │        0.24264484643936157         │
# │  test/pearson:u_component_of_wind  │         0.4464988112449646         │
# │  test/pearson:v_component_of_wind  │        0.21985435485839844         │
# │        test/rmse:aggregate         │         5.496241092681885          │
# │     test/rmse:air_temperature      │         4.585342884063721          │
# │      test/rmse:precipitation       │         6.583727836608887          │
# │   test/rmse:u_component_of_wind    │         5.436487674713135          │
# │   test/rmse:v_component_of_wind    │         5.3794050216674805         │
# └────────────────────────────────────┴────────────────────────────────────┘
# [{'test/rmse:air_temperature': 4.585342884063721,
#   'test/rmse:u_component_of_wind': 5.436487674713135,
#   'test/rmse:v_component_of_wind': 5.3794050216674805,
#   'test/rmse:precipitation': 6.583727836608887,
#   'test/rmse:aggregate': 5.496241092681885,
#   'test/pearson:air_temperature': 0.9770058393478394,
#   'test/pearson:u_component_of_wind': 0.4464988112449646,
#   'test/pearson:v_component_of_wind': 0.21985435485839844,
#   'test/pearson:precipitation': 0.24264484643936157,
#   'test/pearson:aggregate': 0.471500962972641,
#   'test/mean_bias:air_temperature': 0.4095916748046875,
#   'test/mean_bias:u_component_of_wind': 0.02943168580532074,
#   'test/mean_bias:v_component_of_wind': -0.007502904627472162,
#   'test/mean_bias:precipitation': 0.005211532115936279,
#   'test/mean_bias:aggregate': 0.10918299108743668}]

# %% [markdown]
# ClimateLearn provides standard metrics. For forecasting, it displays the latitude weighted RMSE and the latitude weighted ACC. Lower RMSE is better, while higher ACC is better. ACC has a range of [0, 1]. We use latitude weighting to adjust for the fact that we flatten the curved surface of the Earth to a 2D grid, which is squishes information at the equator and stretches information near the poles. For more info about these metrics, see this link: https://geo.libretexts.org/Bookshelves/Meteorology_and_Climate_Science/Practical_Meteorology_(Stull)/20%3A_Numerical_Weather_Prediction_(NWP)/20.7%3A_Forecast_Quality_and_Verfication
#
# Also, you might have noticed the metrics with `aggregate` as the suffix. These represent averages. For example, `lat_rmse:aggregate` is the average of `lat_rmse:temperature` and `lat_rmse:geopotential`.
#
# Besides these metrics, ClimateLearn also provides visualization tools. In the following cell, we first get the denormalization tranfsorm to transform the data returned by the PyTorch Lightning data module, which was normalized to $\mathcal{N}(0,1)$, back into its original range. As we can see the logging messages displayed in the previous cell's output, the persistence model's 0-th test tranfsormation is denormalization.
#
# Then, we visualize the ground truth, prediction, and bias for the persistence prediction made on the 0-th sample of the testing set. Bias is defined as predicted minus observed (see the link provided above). It is useful to gain a visual understanding of model performance. In this example, we can see that persistence generally underpredicts the true values.
#
# For weather forecasting with history greater than 1, the visualization function also returns a value which we save here as `in_graphic`. This graphic can be animated, as seen in the next code cell.

# %%
denorm = bilinear.test_target_transforms[0]
in_graphic = visualize_at_index(
    bilinear,
    dm,
    in_transform=denorm,
    out_transform=denorm,
    variable="2m_temperature",
    src="era5",
    index=0,
)
# Out:
# 0it [00:01, ?it/s]

# %% [markdown]
# Next, we can check deep learning models complexity

# %%
# Set up data
variables = [
    "land_sea_mask",
    "orography",
    "lattitude",
    "toa_incident_solar_radiation",
    "2m_temperature",
    "10m_u_component_of_wind",
    "10m_v_component_of_wind",
    "geopotential",
    "temperature",
    "relative_humidity",
    "specific_humidity",
    "u_component_of_wind",
    "v_component_of_wind",
]
in_vars = []
for var in variables:
    if var in PRESSURE_LEVEL_VARS:
        for level in DEFAULT_PRESSURE_LEVELS:
            in_vars.append(var + "_" + str(level))
    else:
        in_vars.append(var)

# %%
# ERA
dm = IterDataModule(
    task="downscaling",
    inp_root_dir="/app/data/ClimateLearn/processed/weatherbench/era5/5.625deg",
    out_root_dir="/app/data/ClimateLearn/processed/weatherbench/era5/2.8125deg",
    in_vars=in_vars,
    out_vars=["2m_temperature", "temperature_850", "geopotential_500", "10m_u_component_of_wind", "10m_v_component_of_wind"],
    subsample=1,
    batch_size=512,
    num_workers=4,
)
dm.setup()

# %%
# CMIP
dm = IterDataModule(
    task="downscaling",
    inp_root_dir="/app/data/processed/cmip6-cmip6/LR",
    out_root_dir="/app/data/processed/cmip6-cmip6/HR",
    in_vars = ["air_temperature", "u_component_of_wind", "v_component_of_wind", "precipitation", "pressure_sea_level", "specific_humidity", "cloud_cover", "upward_heat_flux", "moisture_in_soil"],
    out_vars = ["air_temperature", "u_component_of_wind", "v_component_of_wind", "precipitation"],
    subsample=1,
    batch_size=32,
    num_workers=4,
)
dm.setup()

# %%
# Retrieve the shape of the 2m temperature data from the first item in the test dataset
temperature_shape = next(iter(dm.data_test.dataset.dataset))[0]["2m_temperature"].shape
print(f"Shape of 2m temperature data: {temperature_shape}")

# Get the shape of the first batch of data from the test dataloader
first_batch_shape = next(iter(dm.test_dataloader()))[0].shape
print(f"Shape of the first batch from test dataloader: {first_batch_shape}")

in_vars, out_vars = dm.get_data_variables()
in_shape, out_shape = dm.get_data_dims()
in_channels, in_height, in_width = in_shape[1:]
out_channels, out_height, out_width = out_shape[1:]

# Printing detailed information about input and output shapes for clarity
print(
    f"Input Channels = {in_channels}, Input Height = {in_height}, Input Width = {in_width}"
)
print(
    f"Output Channels = {out_channels}, Output Height = {out_height}, Output Width = {out_width}"
)
# Out:
# Shape of 2m temperature data: (546, 32, 64)
# Shape of the first batch from test dataloader: torch.Size([512, 49, 32, 64])
# Input Channels = 49, Input Height = 32, Input Width = 64
# Output Channels = 5, Output Height = 64, Output Width = 128

# %%
optim_kwargs={"lr": 3e-4,
            "weight_decay": 1e-5,
            "betas": [0.9, 0.99],
            }
sched_kwargs={"warmup_epochs": 5,
            "max_epochs": 200,
        }

# %%
resnet = load_downscaling_module(data_module=dm, architecture="resnet", optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
unet = load_downscaling_module(data_module=dm, architecture="unet", optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)

deepsd = load_downscaling_module(data_module=dm, architecture="deepsd", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
ynet = load_downscaling_module(data_module=dm, architecture="ynet", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)

edrn = load_downscaling_module(data_module=dm, architecture="edrn", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
esrgan = load_downscaling_module(data_module=dm, architecture="esrgan", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
vit = load_downscaling_module(data_module=dm, architecture="vit", optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
hat = load_downscaling_module(data_module=dm, architecture="hat", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
diffusion = load_downscaling_module(data_module=dm, architecture="diffusion", upsampling=None, optim_kwargs = optim_kwargs, sched_kwargs = sched_kwargs)
# Out:
# Loading architecture: resnet
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: unet
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: deepsd
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: ynet
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: edrn
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: esrgan
# /opt/conda/envs/bias_correction/lib/python3.12/site-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `StructuralSimilarityIndexMeasure` from `torchmetrics` was deprecated and will be removed in 2.0. Import `StructuralSimilarityIndexMeasure` from `torchmetrics.image` instead.
#   _future_warning(
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: vit
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: hat
# /opt/conda/envs/bias_correction/lib/python3.12/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading architecture: diffusion
# Using optimizer associated with architecture
# Using learning rate scheduler associated with architecture
# Loading training loss: mse
# No train transform
# Loading validation loss: rmse
# Loading validation loss: pearson
# Loading validation loss: mean_bias
# Loading validation loss: mse
# Loading validation loss: PSNR
# Loading validation loss: SSIM
# Loading validation loss: KGE
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# No validation transform
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading validation transform: denormalize
# Loading test loss: lat_rmse
# Loading test loss: pearson
# Loading test loss: mean_bias
# Loading test loss: PSNR
# Loading test loss: SSIM
# Loading test loss: KGE
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize
# Loading test transform: denormalize

# %% [markdown]
# #### GFLOPS

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
resnet_params = count_parameters(resnet)
unet_params = count_parameters(unet)
vit_params = count_parameters(vit)
ynet_params = count_parameters(ynet)
deepsd_params = count_parameters(deepsd)
diffusion_params = count_parameters(diffusion)
print(f"# of Resnet params: {resnet_params/1e6:.2f}M")
print(f"# of Unet params: {unet_params/1e6:.2f}M")
print(f"# of ViT params: {vit_params/1e6:.2f}M")
print(f"# of Ynet params: {ynet_params/1e6:.2f}M")
print(f"# of DeepSD params: {deepsd_params/1e6:.2f}M")
print(f"# of Diffusion params: {diffusion_params/1e6:.2f}M")
# Out:
# # of Resnet params: 8.62M
# # of Unet params: 11.73M
# # of ViT params: 1.91M
# # of Ynet params: 1.75M
# # of DeepSD params: 0.31M
# # of Diffusion params: 10.69M

# %%
dm.get_data_dims()
# Out:
# (torch.Size([512, 49, 32, 64]), torch.Size([512, 5, 64, 128]))

# %%
from torch_operation_counter import OperationsCounterMode
from thop import profile
import torch.nn as nn
import torch
device = torch.device("cuda:5" if torch.cuda.is_available() else "cpu")

resnet = resnet.to(device)
unet = unet.to(device)
deepsd = deepsd.to(device)
ynet = ynet.to(device)

edrn = edrn.to(device)
esrgan = esrgan.to(device)
vit = vit.to(device)
hat =hat.to(device)
diffusion = diffusion.to(device)


# Dummy input tensor
x = torch.randn(1, in_channels, in_height, in_width).to(device)
results = []
number_of_operations_per_model = {}
number_of_parameters_per_model = {}
top_1_accuracy_per_model = {}
top_5_accuracy_per_model = {}

for model, model_name in zip([resnet, unet,  deepsd, edrn, esrgan, vit, hat, diffusion], ["resnet", "unet",  "deepsd", "edrn", "esrgan", "vit", "hat", "diffusion"]): 
    print(model_name)
    try:
        with OperationsCounterMode(model) as ops_counter:
            model(x)
    except Exception as e:
        print(f"Model {model_name} failed to evaluate with error: {e}")
        if model_name in number_of_operations_per_model:
            del number_of_operations_per_model[model_name]
        if model_name in number_of_parameters_per_model:
            del number_of_parameters_per_model[model_name]
        if model_name in top_1_accuracy_per_model:
            del top_1_accuracy_per_model[model_name]
        if model_name in top_5_accuracy_per_model:
            del top_5_accuracy_per_model[model_name]
        continue
    total_ops = ops_counter.total_operations / 1e9  # Convert to GigaOPs
    flops, params = profile(model, inputs=(x, ))  # Calculate FLOPs and parameters
    results.append([model_name, total_ops, flops / 1e9, params / 1e6])  # Append results

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create DataFrame
df_results = pd.DataFrame(results, columns=["Model", "Total Operations (GigaOPs)", "GFLOPs", "Params (Millions)"])

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot total operations and GFLOPs
ax1.bar(df_results["Model"], df_results["Total Operations (GigaOPs)"], color='b', alpha=0.6, label='Total Operations (GigaOPs)')
ax1.set_xlabel('Model')
ax1.set_ylabel('Total Operations (GigaOPs)', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create another y-axis for GFLOPs
ax2 = ax1.twinx()
ax2.plot(df_results["Model"], df_results["GFLOPs"], color='r', marker='o', label='GFLOPs')
ax2.set_ylabel('GFLOPs', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add title and show plot
plt.title('Model Comparison: Total Operations and GFLOPs')
fig.tight_layout()

# Display the plot
plt.show()

# %%
df_results
# Out:
#        Model  Total Operations (GigaOPs)      GFLOPs  Params (Millions)
# 0        vit                    3.350987    3.360686           1.646220
# 1     samvit                    2.582271    1.940914           0.836364
# 2     resnet                   70.830565   70.556582           8.605571
# 3       unet                   14.151723   14.763426          11.990339
# 4       ynet                    4.082782    4.101466           1.746792
# 5  diffusion                  500.647804  649.982378          10.685318
# 6     deepsd                    2.564030    2.566873           0.312899

# %% [markdown]
# #### GMAC

# %%
from ptflops import get_model_complexity_info
import sys

# %%
result = {}
size = dm.get_data_dims()[0][1:]

for model, model_name in zip([resnet, unet,  ynet, deepsd, edrn, esrgan, vit, hat, diffusion],
                             ["resnet", "unet",  "ynet", "deepsd", "edrn", "esrgan", "vit", "hat", "diffusion"]): 
    print(model_name)

    macs, params = get_model_complexity_info(model, tuple(size),
                                             as_strings=True,
                                             print_per_layer_stat=True,
                                             ost=sys.stdout)
    result[model_name] = (macs, params)
# Out:
# diffusion
# sampling loop time step: 100%|██████████| 100/100 [00:31<00:00,  3.21it/s]
# DiffusionLitModule(
#   10.67 M, 100.000% Params, 5861.74 GMac, 100.000% MACs,
#   (net): GaussianDiffusion(
#     10.67 M, 100.000% Params, 5861.74 GMac, 100.000% MACs,
#     (denoise_fn): Unet(
#       9.2 M, 86.215% Params, 5833.5 GMac, 99.518% MACs,
#       (cond_proj): ConvTranspose2d(98.37 k, 0.921% Params, 725.25 GMac, 12.373% MACs, 96, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (time_pos_emb): SinusoidalPosEmb(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (mlp): Sequential(
#         33.09 k, 0.310% Params, 3.31 MMac, 0.000% MACs,
#         (0): Linear(16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs, in_features=64, out_features=256, bias=True)
#         (1): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         (2): Linear(16.45 k, 0.154% Params, 1.64 MMac, 0.000% MACs, in_features=256, out_features=64, bias=True)
#       )
#       (downs): ModuleList(
#         (0): ModuleList(
#           (0): ResnetBlock(
#             43.78 k, 0.410% Params, 292.08 GMac, 4.983% MACs,
#             (mlp): Sequential(
#               4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs, in_features=64, out_features=64, bias=True)
#             )
#             (block1): Block(
#               2.37 k, 0.022% Params, 17.46 GMac, 0.298% MACs,
#               (block): Sequential(
#                 2.37 k, 0.022% Params, 17.46 GMac, 0.298% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(2.37 k, 0.022% Params, 17.46 GMac, 0.298% MACs, 4, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(320, 0.003% Params, 2.36 GMac, 0.040% MACs, 4, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             78.02 k, 0.731% Params, 544.53 GMac, 9.289% MACs,
#             (mlp): Sequential(
#               4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs, in_features=64, out_features=64, bias=True)
#             )
#             (block1): Block(
#               36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Downsample(
#             36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#             (conv): Sequential(
#               36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#               (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#               (1): Conv2d(36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs, 64, 64, kernel_size=(3, 3), stride=(2, 2))
#             )
#           )
#         )
#         (1): ModuleList(
#           (0): ResnetBlock(
#             238.08 k, 2.230% Params, 423.49 GMac, 7.225% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               73.86 k, 0.692% Params, 136.13 GMac, 2.322% MACs,
#               (block): Sequential(
#                 73.86 k, 0.692% Params, 136.13 GMac, 2.322% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(73.86 k, 0.692% Params, 136.13 GMac, 2.322% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(8.32 k, 0.078% Params, 15.34 GMac, 0.262% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             303.49 k, 2.843% Params, 544.05 GMac, 9.281% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 272.03 GMac, 4.641% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Downsample(
#             147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#             (conv): Sequential(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#               (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2))
#             )
#           )
#         )
#         (2): ModuleList(
#           (0-1): 2 x ResnetBlock(
#             303.49 k, 2.843% Params, 136.01 GMac, 2.320% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Downsample(
#             147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#             (conv): Sequential(
#               147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#               (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#               (1): Conv2d(147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2))
#             )
#           )
#         )
#         (3): ModuleList(
#           (0): ResnetBlock(
#             934.91 k, 8.758% Params, 105.79 GMac, 1.805% MACs,
#             (mlp): Sequential(
#               16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs, in_features=64, out_features=256, bias=True)
#             )
#             (block1): Block(
#               295.17 k, 2.765% Params, 34.0 GMac, 0.580% MACs,
#               (block): Sequential(
#                 295.17 k, 2.765% Params, 34.0 GMac, 0.580% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(295.17 k, 2.765% Params, 34.0 GMac, 0.580% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#               (block): Sequential(
#                 590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(33.02 k, 0.309% Params, 3.8 GMac, 0.065% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             1.2 M, 11.211% Params, 135.96 GMac, 2.319% MACs,
#             (mlp): Sequential(
#               16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs, in_features=64, out_features=256, bias=True)
#             )
#             (block1): Block(
#               590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#               (block): Sequential(
#                 590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#               (block): Sequential(
#                 590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#       )
#       (ups): ModuleList(
#         (0): ModuleList(
#           (0): ResnetBlock(
#             811.52 k, 7.602% Params, 92.53 GMac, 1.579% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               589.95 k, 5.527% Params, 67.96 GMac, 1.159% MACs,
#               (block): Sequential(
#                 589.95 k, 5.527% Params, 67.96 GMac, 1.159% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(589.95 k, 5.527% Params, 67.96 GMac, 1.159% MACs, 512, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(65.66 k, 0.615% Params, 7.56 GMac, 0.129% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             303.49 k, 2.843% Params, 34.0 GMac, 0.580% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 17.0 GMac, 0.290% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Upsample(
#             262.27 k, 2.457% Params, 120.85 GMac, 2.062% MACs,
#             (conv): Sequential(
#               262.27 k, 2.457% Params, 120.85 GMac, 2.062% MACs,
#               (0): ConvTranspose2d(262.27 k, 2.457% Params, 120.85 GMac, 2.062% MACs, 128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#             )
#           )
#         )
#         (1): ModuleList(
#           (0): ResnetBlock(
#             483.84 k, 4.533% Params, 219.12 GMac, 3.738% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               295.04 k, 2.764% Params, 135.95 GMac, 2.319% MACs,
#               (block): Sequential(
#                 295.04 k, 2.764% Params, 135.95 GMac, 2.319% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(295.04 k, 2.764% Params, 135.95 GMac, 2.319% MACs, 256, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(32.9 k, 0.308% Params, 15.16 GMac, 0.259% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             303.49 k, 2.843% Params, 136.01 GMac, 2.320% MACs,
#             (mlp): Sequential(
#               8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(8.32 k, 0.078% Params, 832.0 KMac, 0.000% MACs, in_features=64, out_features=128, bias=True)
#             )
#             (block1): Block(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#               (block): Sequential(
#                 147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.58 k, 1.383% Params, 68.01 GMac, 1.160% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Upsample(
#             262.27 k, 2.457% Params, 483.42 GMac, 8.247% MACs,
#             (conv): Sequential(
#               262.27 k, 2.457% Params, 483.42 GMac, 8.247% MACs,
#               (0): ConvTranspose2d(262.27 k, 2.457% Params, 483.42 GMac, 8.247% MACs, 128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#             )
#           )
#         )
#         (2): ModuleList(
#           (0): ResnetBlock(
#             205.06 k, 1.921% Params, 370.29 GMac, 6.317% MACs,
#             (mlp): Sequential(
#               4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs, in_features=64, out_features=64, bias=True)
#             )
#             (block1): Block(
#               147.52 k, 1.382% Params, 271.91 GMac, 4.639% MACs,
#               (block): Sequential(
#                 147.52 k, 1.382% Params, 271.91 GMac, 4.639% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(147.52 k, 1.382% Params, 271.91 GMac, 4.639% MACs, 256, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Conv2d(16.45 k, 0.154% Params, 30.32 GMac, 0.517% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): ResnetBlock(
#             78.02 k, 0.731% Params, 136.13 GMac, 2.322% MACs,
#             (mlp): Sequential(
#               4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs,
#               (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               (1): Linear(4.16 k, 0.039% Params, 416.0 KMac, 0.000% MACs, in_features=64, out_features=64, bias=True)
#             )
#             (block1): Block(
#               36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (block2): Block(
#               36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#               (block): Sequential(
#                 36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs,
#                 (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#                 (1): Conv2d(36.93 k, 0.346% Params, 68.07 GMac, 1.161% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#                 (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#               )
#             )
#             (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Upsample(
#             65.6 k, 0.615% Params, 483.66 GMac, 8.251% MACs,
#             (conv): Sequential(
#               65.6 k, 0.615% Params, 483.66 GMac, 8.251% MACs,
#               (0): ConvTranspose2d(65.6 k, 0.615% Params, 483.66 GMac, 8.251% MACs, 64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#             )
#           )
#         )
#       )
#       (mid_block1): ResnetBlock(
#         1.2 M, 11.211% Params, 135.96 GMac, 2.319% MACs,
#         (mlp): Sequential(
#           16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs,
#           (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (1): Linear(16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs, in_features=64, out_features=256, bias=True)
#         )
#         (block1): Block(
#           590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#           (block): Sequential(
#             590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#             (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#             (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (block2): Block(
#           590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#           (block): Sequential(
#             590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#             (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#             (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (mid_attn): Residual(
#         131.33 k, 1.230% Params, 15.13 GMac, 0.258% MACs,
#         (fn): Rezero(
#           131.33 k, 1.230% Params, 15.13 GMac, 0.258% MACs,
#           (fn): LinearAttention(
#             131.33 k, 1.230% Params, 15.13 GMac, 0.258% MACs,
#             (to_qkv): Conv2d(98.3 k, 0.921% Params, 11.32 GMac, 0.193% MACs, 256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (to_out): Conv2d(33.02 k, 0.309% Params, 3.8 GMac, 0.065% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#       (mid_block2): ResnetBlock(
#         1.2 M, 11.211% Params, 135.96 GMac, 2.319% MACs,
#         (mlp): Sequential(
#           16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs,
#           (0): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (1): Linear(16.64 k, 0.156% Params, 1.66 MMac, 0.000% MACs, in_features=64, out_features=256, bias=True)
#         )
#         (block1): Block(
#           590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#           (block): Sequential(
#             590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#             (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#             (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (block2): Block(
#           590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#           (block): Sequential(
#             590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs,
#             (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#             (1): Conv2d(590.08 k, 5.528% Params, 67.98 GMac, 1.160% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (res_conv): Identity(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       )
#       (final_conv): Sequential(
#         37.19 k, 0.348% Params, 274.18 GMac, 4.677% MACs,
#         (0): Block(
#           36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#           (block): Sequential(
#             36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs,
#             (0): ReflectionPad2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (1, 1, 1, 1))
#             (1): Conv2d(36.93 k, 0.346% Params, 272.26 GMac, 4.645% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (2): Mish(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#         )
#         (1): Conv2d(260, 0.002% Params, 1.92 GMac, 0.033% MACs, 64, 4, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (upscaler): Interpolation(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#     (rrdb): RRDBNet(
#       1.47 M, 13.785% Params, 28.24 GMac, 0.482% MACs,
#       (conv_first): Conv2d(2.62 k, 0.025% Params, 48.37 MMac, 0.001% MACs, 9, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (RRDB_trunk): ModuleList(
#         (0-7): 8 x RRDB(
#           180.0 k, 1.686% Params, 3.32 GMac, 0.057% MACs,
#           (RDB1): ResidualDenseBlock_5C(
#             60.0 k, 0.562% Params, 1.11 GMac, 0.019% MACs,
#             (conv1): Conv2d(4.62 k, 0.043% Params, 85.23 MMac, 0.001% MACs, 32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv2): Conv2d(6.93 k, 0.065% Params, 127.7 MMac, 0.002% MACs, 48, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv3): Conv2d(9.23 k, 0.086% Params, 170.16 MMac, 0.003% MACs, 64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv4): Conv2d(11.54 k, 0.108% Params, 212.63 MMac, 0.004% MACs, 80, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv5): Conv2d(27.68 k, 0.259% Params, 510.2 MMac, 0.009% MACs, 96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (lrelu): LeakyReLU(0, 0.000% Params, 1.18 MMac, 0.000% MACs, negative_slope=0.2, inplace=True)
#           )
#           (RDB2): ResidualDenseBlock_5C(
#             60.0 k, 0.562% Params, 1.11 GMac, 0.019% MACs,
#             (conv1): Conv2d(4.62 k, 0.043% Params, 85.23 MMac, 0.001% MACs, 32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv2): Conv2d(6.93 k, 0.065% Params, 127.7 MMac, 0.002% MACs, 48, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv3): Conv2d(9.23 k, 0.086% Params, 170.16 MMac, 0.003% MACs, 64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv4): Conv2d(11.54 k, 0.108% Params, 212.63 MMac, 0.004% MACs, 80, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv5): Conv2d(27.68 k, 0.259% Params, 510.2 MMac, 0.009% MACs, 96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (lrelu): LeakyReLU(0, 0.000% Params, 1.18 MMac, 0.000% MACs, negative_slope=0.2, inplace=True)
#           )
#           (RDB3): ResidualDenseBlock_5C(
#             60.0 k, 0.562% Params, 1.11 GMac, 0.019% MACs,
#             (conv1): Conv2d(4.62 k, 0.043% Params, 85.23 MMac, 0.001% MACs, 32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv2): Conv2d(6.93 k, 0.065% Params, 127.7 MMac, 0.002% MACs, 48, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv3): Conv2d(9.23 k, 0.086% Params, 170.16 MMac, 0.003% MACs, 64, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv4): Conv2d(11.54 k, 0.108% Params, 212.63 MMac, 0.004% MACs, 80, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (conv5): Conv2d(27.68 k, 0.259% Params, 510.2 MMac, 0.009% MACs, 96, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (lrelu): LeakyReLU(0, 0.000% Params, 1.18 MMac, 0.000% MACs, negative_slope=0.2, inplace=True)
#           )
#         )
#       )
#       (trunk_conv): Conv2d(9.25 k, 0.087% Params, 170.46 MMac, 0.003% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (upconv_layers): ModuleList(
#         (0): Conv2d(9.25 k, 0.087% Params, 681.84 MMac, 0.012% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (HRconv): Conv2d(9.25 k, 0.087% Params, 681.84 MMac, 0.012% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (conv_last): Conv2d(1.16 k, 0.011% Params, 85.23 MMac, 0.001% MACs, 32, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (lrelu): LeakyReLU(0, 0.000% Params, 4.72 MMac, 0.000% MACs, negative_slope=0.2)
#     )
#     (ssim_loss): SSIM(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   )
# )

# %%
result
# Out:
# {'resnet': ('616.98 GMac', '8.36 M'),
#  'unet': ('122.68 GMac', '11.6 M'),
#  'ynet': ('30.67 GMac', '1.61 M'),
#  'deepsd': ('7.86 GMac', '106.34 k'),
#  'edrn': ('740.96 GMac', '3.57 M'),
#  'esrgan': ('656.03 GMac', '6.86 M'),
#  'vit': ('727.03 GMac', '3.99 M'),
#  'hat': ('94.42 GMac', '5.12 M')}

# %%
result
# Out:
# {'diffusion': ('5861.74 GMac', '10.67 M')}
